# %%
# Langchain package installation guide: https://python.langchain.com/docs/how_to/installation/

# %% [markdown]
# ### Load API Key

# %%
from dotenv import  load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ### Calling LLM in Cloud using Groq

# %%
from langchain_groq import ChatGroq

# %%
llm = ChatGroq(
    model_name="mixtral-8x7b-32768"
)
llm.invoke("The person to go to moon was")
# Out:
# AIMessage(content='The first person to walk on the moon was Neil Armstrong, an American astronaut and naval aviator. He set foot on the lunar surface on July 20, 1969, during the Apollo 11 mission, which was the culmination of the Space Race between the United States and the Soviet Union. Armstrong\'s famous words, "That\'s one small step for man, one giant leap for mankind," marked a significant milestone in human space exploration and have since become iconic.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 114, 'prompt_tokens': 15, 'total_tokens': 129, 'completion_time': 0.180770338, 'prompt_time': 0.002058923, 'queue_time': 0.027891244, 'total_time': 0.182829261}, 'model_name': 'mixtral-8x7b-32768', 'system_fingerprint': 'fp_c5f20b5bb1', 'finish_reason': 'stop', 'logprobs': None}, id='run-1079f33f-6bc6-4e26-a596-11d37bde1849-0', usage_metadata={'input_tokens': 15, 'output_tokens': 114, 'total_tokens': 129})

# %%
llm = ChatGroq(
    model_name="llama-3.3-70b-versatile",
    temperature=0.6,
    max_tokens=15
)
llm.invoke("The person to go to moon was")
# Out:
# AIMessage(content='The first person to walk on the moon was Neil Armstrong. He stepped out', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 42, 'total_tokens': 57, 'completion_time': 0.054545455, 'prompt_time': 0.008020946, 'queue_time': 0.205376209, 'total_time': 0.062566401}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_1ae2705acb', 'finish_reason': 'length', 'logprobs': None}, id='run-1c303f42-e1a2-4a6b-9593-f624c3785a42-0', usage_metadata={'input_tokens': 42, 'output_tokens': 15, 'total_tokens': 57})

# %% [markdown]
# ### Local Call to LLM Using- Ollama

# %%
from langchain_ollama import ChatOllama

llm = ChatOllama(model="llama3.2:1b",temperature=0, num_predict=15)
llm.invoke("The person to go to moon was")
# Out:
# AIMessage(content='Neil Armstrong and Edwin "Buzz" Aldrin were the first humans to walk', additional_kwargs={}, response_metadata={'model': 'llama3.2:1b', 'created_at': '2024-12-29T00:11:14.8332902Z', 'done': True, 'done_reason': 'length', 'total_duration': 799467800, 'load_duration': 63968100, 'prompt_eval_count': 32, 'prompt_eval_duration': 150951000, 'eval_count': 15, 'eval_duration': 579836000, 'message': Message(role='assistant', content='', images=None, tool_calls=None)}, id='run-58520011-b2fb-4d0d-9f1c-8bce2dbcc762-0', usage_metadata={'input_tokens': 32, 'output_tokens': 15, 'total_tokens': 47})
