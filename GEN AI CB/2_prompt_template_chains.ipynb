# %% [markdown]
# <h2 align="center">Codebasics Gen AI Course: PromptTemplate and Chain</h2>

# %%
from langchain_groq import ChatGroq
from langchain_core.prompts import PromptTemplate

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
prompt = PromptTemplate.from_template("Write two line poem on {topic}")
prompt
# Out:
# PromptTemplate(input_variables=['topic'], input_types={}, partial_variables={}, template='Tell me a joke about {topic}')

# %%
llm = ChatGroq(model_name="llama-3.3-70b-versatile")

chain = prompt | llm

response = chain.invoke({'topic': 'butterfly'})
response
# Out:
# AIMessage(content='Why did the butterfly go to the doctor?\n\nBecause it had a flutter in its heart.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 19, 'prompt_tokens': 41, 'total_tokens': 60, 'completion_time': 0.069249815, 'prompt_time': 0.007964454, 'queue_time': 0.008083548, 'total_time': 0.077214269}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_1ae2705acb', 'finish_reason': 'stop', 'logprobs': None}, id='run-d8042d29-2e63-4ea7-96d2-0d38a5a05b75-0', usage_metadata={'input_tokens': 41, 'output_tokens': 19, 'total_tokens': 60})

# %%
print(response.content)
# Out:
# Why did the butterfly go to the doctor?
#
# Because it had a flutter in its heart.
