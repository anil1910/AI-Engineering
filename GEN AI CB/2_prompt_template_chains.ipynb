# %% [markdown]
# <h2 align="center">Codebasics Gen AI Course: PromptTemplate and Chain</h2>

# %%
from langchain_groq import ChatGroq
from langchain_core.prompts import PromptTemplate

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
prompt = PromptTemplate.from_template("Write two line poem on {topic}")
prompt
# Out:
# PromptTemplate(input_variables=['topic'], input_types={}, partial_variables={}, template='Write two line poem on {topic}')

# %%
llm = ChatGroq(model_name="llama-3.1-8b-instant")

chain = prompt | llm

response = chain.invoke({'topic': 'dogs'})
response
# Out:
# AIMessage(content='Tails that wag, eyes that shine,\nFaithful friends that are always divine.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 19, 'prompt_tokens': 41, 'total_tokens': 60, 'completion_time': 0.053269904, 'completion_tokens_details': None, 'prompt_time': 0.001932153, 'prompt_tokens_details': None, 'queue_time': 0.055384627, 'total_time': 0.055202057}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_ff2b098aaf', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019b791a-e226-79e2-980d-8ef390787d5e-0', usage_metadata={'input_tokens': 41, 'output_tokens': 19, 'total_tokens': 60})

# %%
print(response.content)
# Out:
# Tails that wag, eyes that shine,
# Faithful friends that are always divine.
